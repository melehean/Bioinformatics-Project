# %%
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
from copy import deepcopy

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

import constants
import data
import results_gathering
import ml_importance_methods

# %%
chemical_data = data.prepare_chemical_data()
chemical_data
# Out:
#              pH     EC    TOC  HCHO     Li      B      Al       V      Cr  \
# Sample ID
# R1_06_17   7.65   48.4  0.450  0.08  0.108  3.145   2.340  0.0230  0.0490
# R1_06_18   7.43   65.2  0.870  0.26  0.158  3.418   2.145  0.0140  0.0740
# R1_09_17   7.20   77.5  1.163  0.04  0.121  2.002   2.700  0.0310  0.0590
# R1_09_18   7.34   74.9  1.120  0.21  0.178  2.012   3.147  0.0470  0.0680
# R2_06_17   7.43   92.7  0.975  0.08  0.728  2.981   3.890  0.0440  0.0670
# R2_06_18   7.83   89.3  1.103  0.13  0.928  2.891   2.790  0.0884  0.1350
# R2_09_17   7.13   80.3  1.294  0.04  0.632  2.391   3.920  0.0390  0.0610
# R2_09_18   7.13   84.7  1.167  0.12  0.583  2.389  14.100  0.0705  0.1150
# R3_06_17   7.51  101.7  0.692  0.06  0.625  2.147   5.660  0.1100  0.0690
# R3_06_18   7.49   98.8  0.710  0.16  0.578  3.012   3.987  0.0230  0.0390
# R3_09_17   7.18  110.4  1.143  0.04  0.513  2.631  10.400  0.0580  0.2100
# ...

# %%
family_data, family_names = data.prepare_family_data(drop_unknown_families=False)#data.prepare_family_data(True)
family_data
# Out:
#      R1_06_17  R1_06_18  R1_09_17  R1_09_18  R2_06_17  R2_06_18  R2_09_17  \
# 464       210       110      7433      7072       535       151       896
# 350      2665      3651      2849      7028      1177      1169      1243
# 351       135      1336        59       244       440       195       136
# 179     14005     16800      2756       850      3329      7985      2289
# 418         4         4         8        10        59         5         1
# ..        ...       ...       ...       ...       ...       ...       ...
# 405         0         0         0         0         0         0         0
# 84          0         0         0         0         0         0         0
# 85          0         0         0         0         0         0         0
# 402         0         0         0         0         0         0         0
# 372         0         0         0         0         0         0         0
#
#      R2_09_18  R3_06_17  R3_06_18  ...  R6_09.17  R6_09_18  R7_06_17  \
# ...

# %%
decition_tree_importance = results_gathering.important_relationships_for_all_bacteria(
    chemical_data,
    family_data,
    ml_importance_methods.get_decision_tree_importance,
    model_name="decision_tree",
    importance_threshold=0.9)
#decition_tree_importance

results_to_display_decision_tree = deepcopy(decition_tree_importance)
names = results_gathering.name_lookup(list(results_to_display_decision_tree['Bacteria']), family_names)
results_to_display_decision_tree['Bacteria'] = names
results_to_display_decision_tree
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/pete/Documents/II sem/Odkrywanie wiedzy/Bioinformatics-Project/family_analysis.ipynb Cell 4 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/home/pete/Documents/II%20sem/Odkrywanie%20wiedzy/Bioinformatics-Project/family_analysis.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> #decition_tree_importance
#       <a href='vscode-notebook-cell:/home/pete/Documents/II%20sem/Odkrywanie%20wiedzy/Bioinformatics-Project/family_analysis.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> results_to_display_decision_tree = deepcopy(decition_tree_importance)
# ---> <a href='vscode-notebook-cell:/home/pete/Documents/II%20sem/Odkrywanie%20wiedzy/Bioinformatics-Project/family_analysis.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> names = results_gathering.name_lookup(list(results_to_display_decision_tree['Bacteria']), indices_to_names)
# ...

# %%
decition_tree_importance.to_csv("./results/decition_tree_importance_family.csv")

# %%
xgboost_feature_importance = results_gathering.important_relationships_for_all_bacteria(
    chemical_data,
    family_data,
    ml_importance_methods.get_xgboost_importance,
    model_name="xgboost",
    importance_threshold=1.0)
#xgboost_feature_importance
results_to_display_xgboost = deepcopy(xgboost_feature_importance)
names = results_gathering.name_lookup(list(results_to_display_xgboost['Bacteria']), family_names)
results_to_display_xgboost['Bacteria'] = names
results_to_display_xgboost

# %%
xgboost_feature_importance.to_csv("./results/xgboost_feature_importance_family.csv")

# %%
sorted_xgboost_feature_importance_with_names = xgboost_feature_importance_with_names.sort_values("CV_xgboost", ascending=False)
sorted_xgboost_feature_importance_with_names

#names = results_gathering.name_lookup(list(sorted_xgboost_feature_importance['Bacteria']), family_names)
#sorted_xgboost_feature_importance['Bacteria'] = names
#sorted_xgboost_feature_importance

# %%
sorted_xgboost_feature_importance_with_names.to_csv("./results/sorted_xgboost_feature_importance_family.csv")

# %%
random_forest_feature_importance = results_gathering.important_relationships_for_all_bacteria(
    chemical_data,
    family_data,
    ml_importance_methods.get_random_forest_importance,
    model_name="random_forest",
    importance_threshold=0.19)
results_to_display_rf = deepcopy(random_forest_feature_importance)
names = results_gathering.name_lookup(list(results_to_display_rf['Bacteria']), family_names)
results_to_display_rf['Bacteria'] = names
results_to_display_rf

# %%
random_forest_feature_importance.to_csv("./results/random_forest_feature_importance_family.csv")

# %%
sorted_rf_feature_importance = random_forest_feature_importance.sort_values("CV_random_forest", ascending=False)
sorted_rf_feature_importance

# %%
sorted_rf_feature_importance.to_csv("./results/sorted_rf_feature_importance_family.csv")

# %%
#family_names.to_csv("./results/sorted_rf_feature_importance_family_legend.csv")

# %%
final_results = results_gathering.prepare_final_results(
    chemical_data,
    genus_data,
    decition_tree_importance,
    xgboost_feature_importance,
    random_forest_feature_importance,
)
names = results_gathering.name_lookup(list(final_results['Bacteria']), family_names)
final_results['Bacteria'] = names
final_results

# %%
decition_tree_importance.to_csv("./results/family_analysis_decision_tree.csv")
xgboost_feature_importance.to_csv("./results/family_analysis_xgboost.csv")
random_forest_feature_importance.to_csv("./results/family_analysis_rf.csv")
final_results.to_csv("./results/family_analysis_summary.csv")
